# %%
import torch
import time
import numpy as np
from timeit import timeit
import matplotlib.pyplot as plt
from sys import getsizeof
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns

# %%
matrix_dummy_list_1=list()
for i in range(1,1000,1):
  matrix_dummy_list_1.append([np.random.rand(i,i)])
  #tensor_10000 = tf.convert_to_tensor(matrix_dummy_list_1[i-1])


matrix_dummy_list_2=list()
for i in range(1,1000,1):
  matrix_dummy_list_2.append([np.random.randn(i,i)])

#matrix_dummy_list_1

# %% [markdown]
# #PyTorch

# %%
#PYTORCH 

p=[]
for i in range(1,1000,1):
  p.append(i)

Time_list_py=[]

for k in range(1,1000,1):

  #start=time.time()
  b=torch.rand(k,k)
  start=time.time()
  y=torch.rand(k)
  sol,res,rank,val = torch.linalg.lstsq(b.T,y)
  end = time.time()
  Time_list_py.append(end-start)



len(Time_list_py)

#for k in range(0,100,1):
  #start=time.time()
  #Lambda,U=torch.linalg.eig(matrix_dummy_list_1[k])
  #end = time.time()
  #Time_list_py.append(end-start)
# Out:
# 999

# %% [markdown]
# #PyTorch graph

# %%
plt.figure(figsize=(20,8))
plt.xlim(0,1000)
plt.xlabel('Size of Matrix')
plt.ylabel('Time for exection')
sns.lineplot(data=Time_list_py)
plt.show()

# %% [markdown]
# # TensorFlow

# %%
Time_list_tf=[]
for i in range(1,1000,1):
  #g1 = tf.random.Generator.from_seed(1)
  #b=g1.normal(shape=[i,i])
  A=torch.rand(i,i)
  y=torch.rand(i)
  start=time.time()
  sol,res,rank,val = torch.linalg.lstsq(A.T,y)
  end=time.time()
  Time_list_tf.append(end-start)

len(Time_list_tf)
# Out:
# 999

# %% [markdown]
# #TensorFlow visualization

# %%
plt.figure(figsize=(20,8))
plt.xlim(0,1000)
plt.xlabel('Size of Matrix')
plt.ylabel('Time for exection')
sns.lineplot(data=Time_list_tf)
plt.show()

# %% [markdown]
# #Numpy

# %%
Time_list_numpy=[]
for i in range(1,1000,1):
  #start=time.time()
  A= np.random.rand(i,i)
  y= np.random.rand(i)
  start=time.time()
  w= np.linalg.lstsq(A.T,y,rcond=-1)
  #print('Lambda: ',Lambda)
  #print('U: ', U)
  end=time.time()
  Time_list_numpy.append(end-start)

len(Time_list_numpy)
# Out:
# 999

# %% [markdown]
# #Numpy Visualization

# %%
plt.figure(figsize=(20,8))
plt.xlim(0,1000)
plt.xlabel('Size of Matrix')
plt.ylabel('Time for exection')
sns.lineplot(data=Time_list_numpy)
plt.show()

# %% [markdown]
# # Comparing the three libraries: PyTorch vs. TensorFlow vs. Numpy

# %%
plt.figure(figsize=(30,12))
plt.xlim(0,1000)
plt.xlabel('Size of Matrix')
plt.ylabel('Time for exection')
sns.lineplot(data=Time_list_py,label=' Pytorch ')
sns.lineplot(data=Time_list_tf,label=' TensorFlow ')
sns.lineplot(data=Time_list_numpy,label=' Numpy ')
plt.show()
